# %%
#!pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import time

#!pip install geopy
#!pip install googletrans==3.1.0a0
from googletrans import Translator
from sklearn.feature_extraction.text import TfidfVectorizer
from itertools import combinations
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import WordPunctTokenizer

#import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
#!pip install sentence_transformers
from sentence_transformers import SentenceTransformer, util

# %%
train = pd.read_csv('train.csv')
submission = pd.read_csv('submission.csv')

# %%
def translate_func(text, attempt = 1, max_attempt = 5):
    translator = Translator()
    try:
        return translator.translate(text, dest = "en").text  # 번역
    except:          # 에러의 경우
        if attempt <= max_attempt:   # 5번 이하로 다시 시도
            return translate_func(text, attempt = attempt + 1)
        raise

# %% [markdown]
# # Customer_Job

# %%
original = len(set(train.customer_job))

# %%
# 번역
job_lst = set(train.customer_job)
job_lst_trans = [translate_func(i) if not pd.isna(i) else i for i in job_lst] 
job_dict = pd.DataFrame([job_lst, job_lst_trans]).T
job_dict.columns = ["job_lst", "job_lst_trans"]
job_dict = job_dict.set_index("job_lst").T.to_dict()
train.customer_job = [job_dict[i]["job_lst_trans"] if not pd.isna(i) else i for i in train.customer_job]

job_lst = set(submission.customer_job)
job_lst_trans = [translate_func(i) if not pd.isna(i) else i for i in job_lst] 
job_dict = pd.DataFrame([job_lst, job_lst_trans]).T
job_dict.columns = ["job_lst", "job_lst_trans"]
job_dict = job_dict.set_index("job_lst").T.to_dict()
submission.customer_job = [job_dict[i]["job_lst_trans"] if not pd.isna(i) else i for i in submission.customer_job]

# %%
original_trans = len(set(train.customer_job))

# %%
# 방법 1. TfidfVectorizer와 코사인 유사도 이용
# 글자만 고려
customer_set = sorted(list(set(train.customer_job.dropna())))
le_train = len(customer_set)

# 특수문자 제거 및 토큰화
customer_re = [re.sub(r"[.,~!@#$%^&*\(\)_+=\-~|\\\"\';:\?/\<\>\[\]\{\}]", " ", customer) for customer in customer_set]
customer_re = [customer.strip().lower() for customer in customer_re]
customer_token = [WordPunctTokenizer().tokenize(i) for i in customer_re]

# 불용어 사전
stop = stopwords.words('english')
stop.remove("it") # IT 때문에 삭제

# 불용어 제거
customer_stop = []
for i in customer_token:
    for j in i:
        sent = i
        if j in stop: # 불용어 사전에 있으면 제거
            sent.remove(j)
    customer_stop.append(sent)
customer_stop = [" ".join(i) for i in customer_stop] # 다시 결합

# 문장 벡터화
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(customer_stop)

# %%
# 방법 1-1. 유사하다고 생각되는 모든 값을 그룹화
# 장점 : 카테고리수를 많이 줄일 수 있음, 단점 : 오차가 큼
# 알고리즘
# n*n으로 구성된 유사도 matrix를 순차적으로 돌아가며 확인한다.
# 유사도 기준(standard)를 넘으면 cos_similar에 key를 i번째 값, value를 j 번째 값으로 넣고, customer_stop의 j번째 값을 i번째 값으로 변경


# job들을 각각 하나씩 비교해 코사인 유사도가 standard를 넘는 것을 추출 및 그룹화 되는 첫번째 값으로 전부 변경
standard = 0.6
cos = cosine_similarity(tfidf_matrix, tfidf_matrix) > standard # 유사도가 0.6 초과인 경우만 True
cos_similar = dict()
c = customer_stop.copy() # 테스트를 위한 copy
for i in range(len(cos)):       # i는 1부터 n까지 loop
    for j in range(i+1, len(cos[i])): # 대각을 기준으로 위쪽만 고려(위와 아래는 똑같으니 아래쪽은 생략)
        if c[i] == "" or c[j] == "":    # 빈값이면 그대로 추출
            pass
        elif cos[i][j] and c[i] in cos_similar.keys():  # True 즉, 유사도가 0.6 초과이고, 이미 cos_similar에 있는 경우
            cos_similar[c[j]] = cos_similar[c[i]]  # 디렉터리에 넣음
            c[j] = c[i]            # 값 자체를 변경
        elif cos[i][j]:            # 유사도가 0.6 초과인 경우
            cos_similar[c[j]] = c[i]  
            c[j] = c[i]


# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_job_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_job] # country 기준 conversion으로 변경
len_1 = len(set(customer_job_t)); len_1
# Out:
# 294

# %%
# manage라는 단어를 포함한 단어들이 어떻게 변경되었는지 확인
manage = [i for i in customer_set if "manage" in i]
manage_trans_1 = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in manage]

# %%
# 어떤 값이 변화되었는지 확인하기 위한 코드
# key 값이 변화된 값, value가 변화되기 전의 값으로 구성
def test_func(cos_similar):
    test = dict()
    for i in cos_similar.keys():
        if cos_similar[i] not in test.keys():
            test[cos_similar[i]] = [i]
        else:
            test[cos_similar[i]] += [i]
    return test
test_func(cos_similar)
# Out:
# {'v project manager': ['project manager',
#   'designer project manager',
#   'digital project manager',
#   'general manager project manager',
#   'manager',
#   'owner project manager',
#   'producer project manager',
#   'program project manager',
#   'project manager estimator',
#   'project manager principal',
#   'project manager designer',
#   'project sales manager',
#   'r project manager'],
#  'account management': ['management'],
#  'admin': ['admin assistant', 'it admin'],
#  'administrative': ['administrative assistant'],
#  'architect': ['architect consultant',
#   'architect owner',
#   'project architect',
#   'solutions architect',
#   'consultant',
#   'owner'],
#  'art design': ['architect',
#   'art e design',
#   'design',
#   'design install',
#   'design engineer',
#   'design purchaser',
#   'design install training support',
#   'engineering design install',
#   'hardware design engineer',
#   'senior design engineer'],
#  'hardware': ['art design', 'hardware selection'],
#  'artist lead equipment selection': ['equipment selection'],
#  'arts design': ['arts design'],
#  'assist serving food': ['serving food'],
#  'bidder': ['public bidder'],
#  'broadcasting media': ['media',
#   'media communication',
#   'media communications',
#   'broadcasting media'],
#  'business development': ['business development'],
#  'buyer': ['buyer coordinating', 'requirements buyer'],
#  'program project management': ['v project manager',
#   'director',
#   'estimator',
#   'engagement executive',
#   'general manager',
#   'general management',
#   'program project management',
#   'principal',
#   'sales',
#   'field marketing',
#   'installer sales rep',
#   'technical sales',
#   'facilitator'],
#  'tech': ['it tech', 'tech', 'tech service'],
#  'technician': ['it hardware technician', 'maintenance technician'],
#  'c level executive': ['executive'],
#  'ceo': ['ceo founder'],
#  'chief': ['chief eng',
#   'chief engineer',
#   'chief engineering',
#   'chief physician',
#   'engineer',
#   'engineering'],
#  'community social services': ['community social services'],
#  'component video wall': ['part video wall',
#   'video wall',
#   'component video wall'],
#  'conference room': ['conference'],
#  'conference table': ['conference room'],
#  'business owner': ['consultant purchaser',
#   'design consultant',
#   'technology consultant',
#   'purchaser'],
#  'contractor': ['contractor owner',
#   'electrical contractor',
#   'general contractor',
#   'managing contractor',
#   'sub contractor',
#   'business owner',
#   'product owner',
#   'property owner'],
#  'coordinator': ['marketing coordinator',
#   'parts coordinator',
#   'project coordinator',
#   'purchasing coordinator',
#   'service coordinator'],
#  'creation design': ['creation design'],
#  'decision maker': ['design decision maker',
#   'general manager decision maker',
#   'technical decision maker'],
#  'director': ['chief',
#   'director it',
#   'director engineering',
#   'director operations',
#   'director purchaser',
#   'engineering director',
#   'it director',
#   'project director',
#   'purchasing director',
#   'technical director',
#   'it',
#   'operations',
#   'operations manager',
#   'regional director operations',
#   'lead engineer',
#   'principal engineer',
#   'project engineer',
#   'solution engineer',
#   'system engineer',
#   'systems engineer',
#   'engineering technical',
#   'sales engineering',
#   'engineering technical executive',
#   'technical'],
#  'general manager': ['decision maker',
#   'general manager purchaser',
#   'reseorot general manager',
#   'purchaser it installer',
#   'retailer installer',
#   'seller installer',
#   'system installer',
#   'it administrator',
#   'it manager',
#   'it specialist',
#   'it support',
#   'project administrator',
#   'support',
#   'sales manager'],
#  'designer': ['designer purchaser',
#   'designer producer',
#   'designer engineer',
#   'designer installer',
#   'lead designer',
#   'project designer',
#   'systems designer',
#   'technology designer',
#   'producer',
#   'installer'],
#  'systems administrator': ['designer',
#   'systems design',
#   'systems administrator'],
#  'designer pm gc': ['gc', 'pm'],
#  'designers': ['designers budget'],
#  'developer': ['developer property', 'software developer'],
#  'digital display vs signage need': ['digital signage'],
#  'director finance': ['finance', 'finance executive'],
#  'display': ['display products',
#   'display screen',
#   'restaurant display',
#   'display screen control'],
#  'distributor': ['distributor quotation'],
#  'end user': ['main end user the product',
#   'primary end user',
#   'sourcing quoting end user',
#   'user'],
#  'energy': ['renewable energy'],
#  'engagement executive': ['c level executive',
#   'director finance',
#   'marketing executive',
#   'operations executive',
#   'sales executive'],
#  'equipment planner': ['planner',
#   'planner purchaser',
#   'installation purchaser'],
#  'event marketing': ['marketing'],
#  'facilitator': ['facilitator installation services',
#   'project facilitator',
#   'support facilitator designer'],
#  'facilities': ['facilities operations'],
#  'facility administrator': ['facility manager'],
#  'field marketing': ['event marketing',
#   'marketing operations',
#   'product marketing',
#   'technical marketing',
#   'facilities',
#   'sales operations'],
#  'general management': ['account management',
#   'product management',
#   'project management',
#   'project management program project management'],
#  'gm': ['gm part owner', 'vp gm'],
#  'maintenance': ['technician', 'maintenance supervisor', 'supervisor'],
#  'head': ['head technology', 'project head', 'head'],
#  'healthcare services': ['healthcare services'],
#  'hotel manager': ['hotel tv'],
#  'hr': ['hr posting'],
#  'human resources': ['human resources'],
#  'information technology': ['information technology \u200b',
#   'information technology',
#   'it information technology'],
#  'installer system integrator': ['system designer integrator'],
#  'installer sales rep': ['sales rep'],
#  'integrator': ['it integrator',
#   'reseller integrator',
#   'specifier integrator'],
#  'reseller': ['integrator', 'vendor reseller'],
#  'it project lead': ['lead', 'project lead', 'it project lead', 'team lead'],
#  'it software': ['software solution'],
#  'leader': ['team leader'],
#  'purchasing': ['coordinator',
#   'purchasing agent',
#   'purchasing authority',
#   'purchasing manager',
#   'purchasing supervisor',
#   'purchasing',
#   'maintenance'],
#  'medical imaging specialist': ['medical imaging specialist',
#   'specialist medical imaging'],
#  'medical solution provider': ['medical solution provider',
#   'medical solution provider \u200b',
#   'solution provider'],
#  'military protective services': ['military protective services'],
#  'office it': ['office manager'],
#  'president': ['president sennco', 'vice president'],
#  'primary': ['end user'],
#  'principal': ['principal charge', 'contractor'],
#  'procurement': ['procurement specialist', 'sourcing procurement'],
#  'product research': ['research',
#   'research development',
#   'research installation',
#   'research install',
#   'product research'],
#  'product researcher': ['project researcher'],
#  'purchase': ['purchase install', 'purchase dept'],
#  'quality assurance': ['quality assurance'],
#  'radiology professional': ['radiology professional'],
#  'recommend': ['recommend recommend specific products technologies the solution'],
#  'serving': ['assist serving food', 'serving robot'],
#  'sourcing': ['procurement', 'sourcing'],
#  'studio manager': ['tv studio manager'],
#  'supplier': ['supplier installation'],
#  'surgery professional': ['surgery professional \u200b']}

# %%
# 방법 1-2. 유사하다고 생각되는 모든 값을 그룹화
# 장점 : 조금더 깐깐하게 그룹화해서 오차가 적음
# 단점 : 카테고리 수가 많이 줄어들진 않음
# 알고리즘 : 유사도가 높은 것부터 차례로 cos_similar에 넣음

# 유사도 기준
standard = 0.6
cos = cosine_similarity(tfidf_matrix, tfidf_matrix)

# 대각행렬은 nan -> 고려하지 않기 위해
cos = np.array(cos)
np.fill_diagonal(cos, np.nan)

cos_similar = dict()
cos = pd.DataFrame(cos)
c = customer_stop.copy()
while cos.max().max() > standard: # 전부 유사도가 0.6 이하가 될때까지
    i = cos.max(axis = 1).idxmax()  # 최댓값을 가진 행 추출
    j = cos.iloc[i,:].idxmax()     # 최댓값을 가진 열 추출
    
    if customer_stop[i] == "" or customer_stop[j] == "":  # 둘 중 하나라도 빈값이면 수행 x
        pass
    elif c[i] in cos_similar.keys():  # 이미 딕셔너리에 있는 경우
        cos_similar[c[j]] = cos_similar[c[i]]
    else:
        cos_similar[c[j]] = c[i]
    
    cos.iloc[i, j] = 0  # 처리된 단어간의 유사도는 0으로 설정
    cos.iloc[j, i] = 0

c = [cos_similar[i] if i in cos_similar.keys() else i for i in c] # 저장된 딕셔너리에 맞춰 값 변경

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_job_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_job] # country 기준 conversion으로 변경
len_2 = len(set(customer_job_t)); len_2
# Out:
# 313

# %%
manage_trans_2 = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in manage]

# %%
test_func(cos_similar)
# Out:
# {'art design': ['art design',
#   'art e design',
#   'design consultant',
#   'design',
#   'design install',
#   'design install training support'],
#  'business development': ['business development'],
#  'creation design': ['creation design'],
#  'director': ['engineering director',
#   'director it',
#   'it director',
#   'operations manager',
#   'it integrator',
#   'purchasing director',
#   'technical director',
#   'project director',
#   'it',
#   'director operations',
#   'director purchaser',
#   'it specialist',
#   'director engineering',
#   'it administrator',
#   'project administrator',
#   'it support'],
#  'human resources': ['human resources'],
#  'information technology': ['information technology \u200b',
#   'information technology',
#   'it information technology'],
#  'medical imaging specialist': ['medical imaging specialist',
#   'specialist medical imaging'],
#  'medical solution provider': ['medical solution provider',
#   'medical solution provider \u200b',
#   'solution provider'],
#  'military protective services': ['military protective services'],
#  'quality assurance': ['quality assurance'],
#  'radiology professional': ['radiology professional'],
#  'v project manager': ['project manager',
#   'r project manager',
#   'sales rep',
#   'general manager purchaser',
#   'purchaser',
#   'project manager estimator',
#   'producer project manager',
#   'project sales manager',
#   'project manager principal',
#   'sales',
#   'digital project manager',
#   'purchaser it installer'],
#  'arts design': ['arts design'],
#  'tech': ['tech', 'it tech', 'tech service'],
#  'community social services': ['community social services'],
#  'designer': ['project manager designer',
#   'general manager project manager',
#   'project designer',
#   'project lead',
#   'designer project manager',
#   'lead designer',
#   'reseorot general manager',
#   'designer engineer',
#   'designer purchaser',
#   'designer installer',
#   'technology designer',
#   'systems engineer',
#   'systems designer',
#   'designer producer'],
#  'estimator': ['estimator'],
#  'healthcare services': ['healthcare services'],
#  'designer installer': ['installer',
#   'system installer',
#   'retailer installer',
#   'seller installer'],
#  'media': ['media communication', 'media communications'],
#  'general management': ['product management'],
#  'program project management': ['program project management',
#   'project management',
#   'program project manager'],
#  'product research': ['research development',
#   'research',
#   'research installation',
#   'research install'],
#  'procurement': ['sourcing procurement', 'procurement specialist'],
#  'surgery professional': ['surgery professional \u200b'],
#  'management': ['project management program project management'],
#  'decision maker': ['design decision maker', 'technical decision maker'],
#  'it': ['sales manager', 'manager', 'it manager'],
#  'head': ['project head', 'head technology'],
#  'facilitator': ['project facilitator', 'facilitator installation services'],
#  'studio manager': ['tv studio manager'],
#  'engineering technical': ['engineering technical executive'],
#  'architect': ['project architect',
#   'architect owner',
#   'architect consultant',
#   'consultant',
#   'solutions architect'],
#  'purchasing': ['purchasing manager',
#   'purchasing coordinator',
#   'purchasing supervisor',
#   'purchasing agent',
#   'purchasing authority'],
#  'admin': ['it admin', 'admin assistant'],
#  'director finance': ['finance', 'finance executive'],
#  'coordinator': ['project coordinator',
#   'service coordinator',
#   'parts coordinator'],
#  'designer producer': ['producer'],
#  'component video wall': ['video wall', 'part video wall'],
#  'it support': ['support', 'support facilitator designer'],
#  'chief': ['engineering design install',
#   'principal engineer',
#   'engineering',
#   'chief engineer',
#   'engineer',
#   'chief engineering',
#   'chief eng',
#   'chief physician',
#   'system engineer'],
#  'primary': ['primary end user'],
#  'serving': ['serving food', 'serving robot'],
#  'engineer': ['project engineer'],
#  'facilities': ['facilities operations', 'operations'],
#  'general manager': ['general manager decision maker'],
#  'display screen': ['display screen control'],
#  'supplier': ['supplier installation'],
#  'planner': ['planner purchaser'],
#  'maintenance': ['supervisor',
#   'maintenance technician',
#   'maintenance supervisor'],
#  'leader': ['team leader'],
#  'equipment planner': ['planner'],
#  'hardware': ['hardware design engineer',
#   'hardware selection',
#   'it hardware technician'],
#  'contractor': ['owner project manager',
#   'contractor owner',
#   'general contractor',
#   'product owner',
#   'managing contractor',
#   'electrical contractor',
#   'sub contractor'],
#  'designer engineer': ['lead engineer', 'solution engineer'],
#  'installer system integrator': ['system designer integrator'],
#  'integrator': ['reseller integrator', 'specifier integrator'],
#  'purchase': ['purchase install', 'purchase dept'],
#  'consultant': ['consultant purchaser', 'technology consultant'],
#  'marketing': ['marketing coordinator',
#   'technical marketing',
#   'marketing executive',
#   'operations executive',
#   'marketing operations',
#   'product marketing'],
#  'sales': ['sales engineering',
#   'technical sales',
#   'sales executive',
#   'sales operations'],
#  'administrative': ['administrative assistant'],
#  'developer': ['software developer', 'developer property'],
#  'distributor': ['distributor quotation'],
#  'director engineering': ['engineering technical', 'technical'],
#  'director operations': ['regional director operations'],
#  'end user': ['user',
#   'sourcing quoting end user',
#   'main end user the product'],
#  'office it': ['office manager'],
#  'artist lead equipment selection': ['equipment selection'],
#  'design engineer': ['senior design engineer'],
#  'bidder': ['public bidder'],
#  'ceo': ['ceo founder'],
#  'designers': ['designers budget'],
#  'energy': ['renewable energy'],
#  'hr': ['hr posting'],
#  'lead': ['team lead'],
#  'business owner': ['owner', 'property owner'],
#  'account management': ['management'],
#  'recommend': ['recommend recommend specific products technologies the solution'],
#  'it project lead': ['lead'],
#  'buyer': ['buyer coordinating', 'requirements buyer'],
#  'conference table': ['conference'],
#  'gm': ['vp gm', 'gm part owner'],
#  'president': ['president sennco', 'vice president'],
#  'facility administrator': ['facility manager'],
#  'display': ['display products', 'display screen', 'restaurant display'],
#  'design': ['design engineer', 'design purchaser'],
#  'product researcher': ['project researcher'],
#  'principal': ['principal charge'],
#  'reseller': ['vendor reseller'],
#  'hotel manager': ['hotel tv'],
#  'broadcasting media': ['media'],
#  'designer pm gc': ['gc', 'pm'],
#  'engagement executive': ['executive'],
#  'field marketing': ['marketing'],
#  'digital display vs signage need': ['digital signage'],
#  'it software': ['software solution'],
#  'systems administrator': ['systems design']}

# %%
# 방법 1-3. 길이가 적은 값으로 그룹화
# 장점 : 핵심 단어로 분류가 가능
# 단점 : 더 깐깐하게 그룹화
# 알고리즘
# 가장 유사도가 높은 두 단어를 추출
# 두 단어 중 길이가 짧은 것을 value, 길이가 긴 것을 key로 설정해 길이가 긴 것으로 짧은 것으로 변환할 수 있도록 함
# 길이가 짧은 단어의 유사도를 두고, 길이가 긴 단어의 유사도는 삭제 -> 그래야 길이가 긴 단어와 유사도가 높은 단어가 포함되지 않음
standard = 0.6
cos = cosine_similarity(tfidf_matrix, tfidf_matrix)

# 대각행렬은 nan -> 고려하지 않기 위해
cos = np.array(cos)
np.fill_diagonal(cos, np.nan)

cos_similar = dict()
cos = pd.DataFrame(cos)
c = customer_stop.copy()

while cos.max().max() > standard: # 전부 유사도가 0.6 이하가 될때까지
    i = cos.max(axis = 1).idxmax()  # 최댓값을 가진 행 추출
    j = cos.iloc[i,:].idxmax()     # 최댓값을 가진 열 추출
    
    # 처리된 단어간의 유사도는 0으로 설정
    cos.iloc[i, j] = 0
    cos.iloc[j, i] = 0

    # 길이가 짧으면 idx, 길면 del_idx
    idx, del_idx = [i, j] if len(c[i]) <= len(c[j]) else [j, i]
    
    if c[idx] == "": # ""는 무조건 짧은 쪽일 것이고, 만약 idx가 ""이면 ""인 쪽을 삭제하기 위해 del_idx로 변경 -> ""는 it나 tech 등 상관없는 단어와 유사도가 높음
        idx, del_idx = del_idx, idx
    elif c[idx] in cos_similar.keys():  # 이미 딕셔너리에 있는 경우
        cos_similar[c[del_idx]] = cos_similar[c[idx]]
    else:
        cos_similar[c[del_idx]] = c[idx]
    
    # 길이가 긴 단어를 우선 삭제 -> it, it developer, tech developer 이라고 한다면 it라는 핵심 단어로 우선 그룹화 그러면 it와 관련있는 단어들이 그룹화
    # 이전 알고리즘은 it developer가 먼저 나오거나 유사도가 높으면 위 세개의 단어가 it developer로 묶일 수 있었음 -> 그래서 이 알고리즘이 더 깐깐
    # 단어 길이가 짧은 것은 핵심단어라는 뜻이므로 이를 기준으로 그룹화
    cos = cos.drop(del_idx).drop(del_idx, axis = 1).reset_index(drop = True) # 길이가 긴 단어의 유사도 행을 우선 삭제
    cos.columns = list(range(len(cos))) # index와 columns 정렬
    del c[del_idx]  # 단어 자체도 삭제
    
c = [cos_similar[i] if i in cos_similar.keys() else i for i in customer_stop]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_job_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_job] # country 기준 conversion으로 변경
len_3 = len(set(customer_job_t)); len_3
# Out:
# 323

# %%
manage_trans_3 = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in manage]

# %%
test_func(cos_similar)
# Out:
# {'design': ['art design', 'design install'],
#  'art design': ['art e design'],
#  'business development': ['business development'],
#  'creation design': ['creation design'],
#  'director engineering': ['engineering director'],
#  'human resources': ['human resources'],
#  'information technology': ['information technology \u200b',
#   'information technology',
#   'it information technology'],
#  'medical imaging specialist': ['medical imaging specialist',
#   'specialist medical imaging'],
#  'solution provider': ['medical solution provider'],
#  'medical solution provider': ['medical solution provider \u200b'],
#  'military protective services': ['military protective services'],
#  'quality assurance': ['quality assurance'],
#  'radiology professional': ['radiology professional'],
#  'project manager': ['v project manager',
#   'r project manager',
#   'owner project manager',
#   'program project manager'],
#  'arts design': ['arts design'],
#  'manager': ['project manager'],
#  'tech': ['tech', 'it tech', 'tech service'],
#  'community social services': ['community social services'],
#  'designer project manager': ['project manager designer'],
#  'director': ['director it', 'project director'],
#  'director it': ['it director'],
#  'estimator': ['estimator', 'project manager estimator'],
#  'healthcare services': ['healthcare services'],
#  'installer': ['installer',
#   'designer installer',
#   'system installer',
#   'purchaser it installer',
#   'retailer installer',
#   'seller installer'],
#  'media': ['media communication',
#   'media communications',
#   'broadcasting media'],
#  'management': ['product management',
#   'project management',
#   'general management',
#   'account management'],
#  'program project management': ['program project management',
#   'project management program project management'],
#  'research': ['research development',
#   'product research',
#   'research installation',
#   'research install'],
#  'sourcing': ['sourcing procurement'],
#  'surgery professional': ['surgery professional \u200b'],
#  'decision maker': ['design decision maker',
#   'technical decision maker',
#   'general manager decision maker'],
#  'general manager': ['general manager project manager',
#   'general manager purchaser',
#   'reseorot general manager'],
#  'sales manager': ['project sales manager'],
#  'sales rep': ['installer sales rep'],
#  'project designer': ['designer project manager'],
#  'head': ['project head', 'head technology'],
#  'facilitator': ['project facilitator',
#   'support facilitator designer',
#   'facilitator installation services'],
#  'project lead': ['it project lead'],
#  'studio manager': ['tv studio manager'],
#  'engineering technical': ['engineering technical executive'],
#  'architect': ['project architect',
#   'architect owner',
#   'architect consultant',
#   'solutions architect'],
#  'system installer': ['installer system integrator'],
#  'purchasing': ['purchasing manager',
#   'purchasing director',
#   'purchasing agent',
#   'purchasing authority'],
#  'admin': ['it admin', 'admin assistant'],
#  'finance': ['director finance', 'finance executive'],
#  'coordinator': ['project coordinator',
#   'marketing coordinator',
#   'purchasing coordinator',
#   'service coordinator',
#   'parts coordinator'],
#  'lead': ['project lead', 'lead designer', 'lead engineer', 'team lead'],
#  'operations': ['operations manager',
#   'director operations',
#   'sales operations'],
#  'producer': ['designer producer', 'producer project manager'],
#  'video wall': ['part video wall', 'component video wall'],
#  'sales': ['sales manager', 'sales rep'],
#  'support': ['it support'],
#  'design install': ['engineering design install'],
#  'end user': ['primary end user'],
#  'integrator': ['it integrator', 'specifier integrator'],
#  'serving food': ['assist serving food'],
#  'consultant': ['design consultant',
#   'consultant purchaser',
#   'technology consultant'],
#  'engineer': ['project engineer',
#   'design engineer',
#   'designer engineer',
#   'solution engineer',
#   'system engineer',
#   'systems engineer'],
#  'facilities': ['facilities operations'],
#  'purchaser': ['design purchaser',
#   'director purchaser',
#   'designer purchaser',
#   'installation purchaser'],
#  'principal': ['principal engineer',
#   'project manager principal',
#   'principal charge'],
#  'engineering': ['director engineering',
#   'sales engineering',
#   'engineering technical'],
#  'technical': ['technical director', 'technical sales', 'technical marketing'],
#  'display screen': ['display screen control'],
#  'supplier': ['supplier installation'],
#  'designer': ['project designer', 'technology designer'],
#  'planner': ['planner purchaser', 'equipment planner'],
#  'chief': ['chief engineer',
#   'chief engineering',
#   'chief eng',
#   'chief physician'],
#  'it': ['it manager', 'it specialist', 'it administrator'],
#  'supervisor': ['purchasing supervisor'],
#  'leader': ['team leader'],
#  'procurement': ['procurement specialist'],
#  'contractor': ['contractor owner',
#   'general contractor',
#   'managing contractor',
#   'electrical contractor',
#   'sub contractor'],
#  'reseller': ['reseller integrator', 'vendor reseller'],
#  'purchase': ['purchase install', 'purchase dept'],
#  'executive': ['sales executive',
#   'marketing executive',
#   'operations executive',
#   'c level executive',
#   'engagement executive'],
#  'administrative': ['administrative assistant'],
#  'technician': ['maintenance technician', 'it hardware technician'],
#  'developer': ['software developer', 'developer property'],
#  'distributor': ['distributor quotation'],
#  'maintenance': ['maintenance supervisor'],
#  'marketing': ['marketing operations',
#   'product marketing',
#   'event marketing',
#   'field marketing'],
#  'user': ['end user'],
#  'hardware': ['hardware selection', 'hardware design engineer'],
#  'office it': ['office manager'],
#  'equipment selection': ['artist lead equipment selection'],
#  'bidder': ['public bidder'],
#  'ceo': ['ceo founder'],
#  'designers': ['designers budget'],
#  'energy': ['renewable energy'],
#  'hr': ['hr posting'],
#  'owner': ['product owner', 'business owner', 'property owner'],
#  'serving': ['serving food', 'serving robot'],
#  'recommend': ['recommend recommend specific products technologies the solution'],
#  'buyer': ['buyer coordinating', 'requirements buyer'],
#  'conference': ['conference room', 'conference table'],
#  'gm': ['vp gm', 'gm part owner'],
#  'president': ['president sennco', 'vice president'],
#  'facility manager': ['facility administrator'],
#  'display': ['display products', 'display screen', 'restaurant display'],
#  'product researcher': ['project researcher'],
#  'hotel tv': ['hotel manager'],
#  'systems design': ['systems designer', 'systems administrator'],
#  'gc': ['designer pm gc'],
#  'digital signage': ['digital display vs signage need'],
#  'it software': ['software solution']}

# %%
# 방법 2. 사전학습모델 SentenceTransformer
# 단어의 숨겨진 의미까지 파악해 위 방법보다 유연
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
customer_set = sorted(list(set(train.customer_job.dropna())))
le_train = len(customer_set)

# 특수문자 제거 및 토큰화
customer_re = [re.sub(r"[.,~!@#$%^&*\(\)_+=\-~|\\\"\';:\?/\<\>\[\]\{\}]", " ", customer) for customer in customer_set]
customer_re = [customer.strip().lower() for customer in customer_re]
customer_token = [WordPunctTokenizer().tokenize(i) for i in customer_re]

# 불용어 사전
stop = stopwords.words('english')
stop.remove("it") # IT 때문에 삭제

# 불용어 제거
customer_stop = []
for i in customer_token:
    for j in i:
        sent = i
        if j in stop: # 불용어 사전에 있으면 제거
            sent.remove(j)
    customer_stop.append(sent)
customer_stop = [" ".join(i) for i in customer_stop] # 다시 결합

embeddings = model.encode(customer_stop, convert_to_tensor=True)
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
# 방법 2-1. 방법 1-1과 동일
standard = 0.6

cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)
cosine_scores = cosine_scores>standard
cos_similar = dict()
c = customer_stop.copy() # 테스트를 위한 copy
for i in range(len(cos)):
    for j in range(i+1, len(cosine_scores[i])):
        if c[i] == "" or c[j] == "":
            pass
        elif cosine_scores[i][j] and c[i] in cos_similar.keys():
            cos_similar[c[j]] = cos_similar[c[i]]
            c[j] = c[i]
        elif cosine_scores[i][j]:
            cos_similar[c[j]] = c[i]
            c[j] = c[i]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_job_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_job] # country 기준 conversion으로 변경
len_4 = len(set(customer_job_t)); len_4
# Out:
# 257

# %%
manage_trans_4 = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in manage]

# %%
test_func(cos_similar)
# Out:
# {'v project manager': ['project manager',
#   'construction manager',
#   'designer project manager',
#   'digital project manager',
#   'general manager project manager',
#   'it manager',
#   'owner project manager',
#   'producer project manager',
#   'program project management',
#   'program project manager',
#   'project administrator',
#   'project coordinator',
#   'project director',
#   'project engineer',
#   'project head',
#   'project manage',
#   'project management',
#   'project management program project management',
#   'project manager estimator',
#   'project manager principal',
#   'project manager designer',
#   'project sales manager',
#   'projection manager',
#   'r project manager',
#   'site manager',
#   'tv studio manager'],
#  'account executive manager': ['account management',
#   'office manager',
#   'operations manager',
#   'accounting',
#   'asset management',
#   'general management',
#   'management',
#   'product management',
#   'accounts payable'],
#  'it project lead': ['v project manager'],
#  'admin': ['admin assistant', 'it admin', 'administrative assistant'],
#  'it hardware technician': ['admin',
#   'clinical specialist',
#   'it software',
#   'software solution',
#   'it hardware technician',
#   'medical solution provider',
#   'specialist medical imaging',
#   'surgery professional',
#   'medical solution provider \u200b',
#   'solution provider'],
#  'administration': ['administrative',
#   'integration',
#   'integrator',
#   'hotel manager',
#   'network administrator',
#   'pacs administrator',
#   'platform administrator'],
#  'advertising': ['advertising promotions team',
#   'marketing',
#   'marketing executive',
#   'marketing operations',
#   'field outside sales',
#   'sale'],
#  'architect': ['architect ass interiores',
#   'architect consultant',
#   'architect owner',
#   'project architect',
#   'design consultant',
#   'building owner',
#   'contractor owner',
#   'owner',
#   'property owner',
#   'business owner',
#   'product owner',
#   'general manager',
#   'manager',
#   'project designer',
#   'project facilitator',
#   'project lead',
#   'project researcher',
#   'project team member',
#   'resource manager',
#   'sales manager',
#   'imaging administrator',
#   'managing partner'],
#  'lead': ['architect', 'leader', 'team lead', 'lead', 'team leader'],
#  'head': ['art design',
#   'tech',
#   'head technology',
#   'information technology \u200b',
#   'it information technology',
#   'media communication',
#   'media communications',
#   'designer installer',
#   'installer sales rep',
#   'furnish install',
#   'installer system integrator',
#   'it integrator',
#   'reseller integrator',
#   'specifier integrator',
#   'system designer integrator'],
#  'art design': ['art installation',
#   'art e design',
#   'arts design',
#   'creation design',
#   'design',
#   'design installation company',
#   'planning installation',
#   'research installation',
#   'design build',
#   'designers',
#   'design purchaser',
#   'designer'],
#  'marketing coordinator': ['account executive manager',
#   'advertising',
#   'parts coordinator',
#   'purchasing coordinator',
#   'service coordinator',
#   'sales executive',
#   'sales operations'],
#  'assist serving food': ['serving food'],
#  'business development': ['business development', 'research development'],
#  'buyer': ['buyer coordinating', 'dealer'],
#  'tech': ['energy',
#   'engineering',
#   'engineering technical',
#   'information technology',
#   'it tech',
#   'tech service',
#   'technical'],
#  'technician': ['technology consultant', 'technology designer'],
#  'cctv monitoring': ['cctv view'],
#  'ceo': ['ceo founder', 'coo'],
#  'chief': ['chief eng',
#   'chief engineer',
#   'chief engineering',
#   'chief physician',
#   'president',
#   'design engineer',
#   'designer engineer',
#   'director engineering',
#   'engineer',
#   'engineering technical executive',
#   'engineering director',
#   'lead engineer',
#   'principal engineer',
#   'senior design engineer',
#   'system engineer',
#   'systems engineer',
#   'doctor'],
#  'decision maker': ['chief',
#   'consult',
#   'design decision maker',
#   'general manager decision maker',
#   'technical decision maker',
#   'decision maker',
#   'designer pm gc',
#   'designers budget',
#   'developer',
#   'producer',
#   'developer property',
#   'software developer',
#   'real estate',
#   'director it',
#   'director finance',
#   'director lodging',
#   'regional director operations',
#   'sales engineering'],
#  'clinical specialist': ['it specialist',
#   'medical imaging specialist',
#   'procurement specialist'],
#  'commercial director': ['creative director',
#   'director',
#   'director operations',
#   'it director',
#   'program directors',
#   'technical director',
#   'facility manager'],
#  'community social services': ['community social services'],
#  'community theater': ['home theater'],
#  'component video wall': ['part video wall', 'video wall'],
#  'conference room': ['conference table', 'conference', 'conference room'],
#  'consult': ['consultant',
#   'consulting',
#   'consultant purchaser',
#   'designer purchaser',
#   'director purchaser',
#   'general manager purchaser',
#   'installation purchaser',
#   'planner purchaser'],
#  'contractor': ['signage subcontractor p',
#   'sub contractor',
#   'lead designer',
#   'technician',
#   'designer creative technologist',
#   'designer producer',
#   'design install',
#   'hardware design engineer',
#   'solution engineer',
#   'systems designer',
#   'renewable energy'],
#  'federal government contractor': ['contractor',
#   'general contractor',
#   'managing contractor'],
#  'contributor': ['distribution',
#   'distributor',
#   'contributor',
#   'distributor quotation'],
#  'hardware': ['commercial director',
#   'facilitator',
#   'federal government contractor',
#   'hardware selection',
#   'managing director',
#   'ordering manager'],
#  'department secretary': ['it department'],
#  'design install': ['design install training support',
#   'engineering design install',
#   'research install',
#   'facilitator installation services',
#   'supplier installation'],
#  'designer installer': ['installer',
#   'purchaser it installer',
#   'retailer installer',
#   'seller installer',
#   'system installer'],
#  'digital display vs signage need': ['digital signage'],
#  'development coordinator procurement': ['development coordinator procurement'],
#  'display': ['display products',
#   'display screen',
#   'display',
#   'display screen control'],
#  'education': ['educator', 'teacher'],
#  'end user': ['main end user the product',
#   'primary end user',
#   'user',
#   'end user'],
#  'engagement executive': ['operations executive'],
#  'estimator': ['estimator'],
#  'event marketing': ['field marketing',
#   'product marketing',
#   'technical marketing'],
#  'execution': ['executive'],
#  'facilitator': ['facilities',
#   'facilities operations',
#   'facility administrator',
#   'it administrator',
#   'studio manager'],
#  'field outside sales': ['event marketing'],
#  'finance': ['finance executive'],
#  'furnish install': ['purchase install'],
#  'gc': ['gm'],
#  'graphic design': ['graphic color art'],
#  'healthcare professionals': ['healthcare services',
#   'healthcare professionals'],
#  'hotel manager': ['hotel tv'],
#  'hr': ['hr posting'],
#  'human resources': ['human resources'],
#  'imaging administrator': ['managing employee', 'systems administrator'],
#  'media': ['head', 'media'],
#  'interior designer': ['interior stylist', 'hardware'],
#  'it': ['department secretary', 'office it', 'it'],
#  'it support': ['support'],
#  'maintenance': ['maintenance supervisor',
#   'maintenance technician',
#   'maintenance'],
#  'manger': ['ranger 2'],
#  'manufacturer': ['manufacturing factory plant', 'supplier'],
#  'military protective services': ['military protective services']}

# %%
# 방법 2-2. 방법 1-2와 동일

standard = 0.6

cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)
cosine_scores = np.array(cosine_scores)
np.fill_diagonal(cosine_scores, np.nan)

cos_similar = dict()
cosine_scores = pd.DataFrame(cosine_scores)
c = customer_stop.copy()
while cosine_scores.max().max() > standard:
    i = cosine_scores.max(axis = 1).idxmax()
    j = cosine_scores.iloc[i,:].idxmax()
    
    
    if customer_stop[i] == "" or customer_stop[j] == "":
        pass
    elif customer_stop[i] in cos_similar.keys():
        cos_similar[c[j]] = cos_similar[c[i]]
    else:
        cos_similar[c[j]] = c[i]
    
    cosine_scores.iloc[i, j] = 0
    cosine_scores.iloc[j, i] = 0
    
c = [cos_similar[i] if i in cos_similar.keys() else i for i in customer_stop]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_job_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_job] # country 기준 conversion으로 변경
len_5 = len(set(customer_job_t)); len_5
# Out:
# 251

# %%
manage_trans_5 = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in manage]

# %%
test_func(cos_similar)
# Out:
# {'art design': ['art design',
#   'creation design',
#   'program project management',
#   'arts design',
#   'designers',
#   'art e design',
#   'project management',
#   'designer project manager',
#   'design engineer',
#   'designer producer',
#   'purchaser it installer',
#   'art installation',
#   'design',
#   'supplier installation',
#   'engineering',
#   'design installation company',
#   'design purchaser',
#   'solutions architect',
#   'installation purchaser'],
#  'clinical specialist': ['medical solution provider',
#   'medical imaging specialist',
#   'surgery professional'],
#  'business development': ['research development', 'business development'],
#  'v project manager': ['project manager',
#   'project management program project management',
#   'project lead',
#   'project sales manager',
#   'owner project manager',
#   'digital project manager',
#   'project coordinator',
#   'manager',
#   'site manager',
#   'project manage',
#   'it manager',
#   'tv studio manager',
#   'project team member',
#   'studio manager',
#   'resource manager'],
#  'energy': ['tech',
#   'engineering technical',
#   'technical director',
#   'sales engineering',
#   'renewable energy',
#   'energy'],
#  'community social services': ['community social services'],
#  'director': ['director it',
#   'project director',
#   'director finance',
#   'program directors'],
#  'estimator': ['estimator'],
#  'healthcare professionals': ['healthcare services'],
#  'designer installer': ['installer', 'retailer installer'],
#  'information technology': ['media communication',
#   'media communications',
#   'it information technology',
#   'information technology \u200b',
#   'software solution',
#   'it software'],
#  'military protective services': ['military protective services'],
#  'account executive manager': ['product management',
#   'management',
#   'account management',
#   'accounting',
#   'asset management',
#   'product research',
#   'general management',
#   'accounts payable',
#   'research products prices'],
#  'radiology professional': ['radiology professional'],
#  'sourcing': ['sourcing procurement'],
#  'head': ['information technology', 'head technology'],
#  'quality assurance': ['quality assurance'],
#  'human resources': ['human resources'],
#  'architect': ['systems engineer',
#   'projection manager',
#   'r project manager',
#   'project manager principal',
#   'engineering design install',
#   'senior design engineer',
#   'architect consultant',
#   'technical',
#   'project architect',
#   'director engineering',
#   'design consultant',
#   'principal engineer',
#   'architect ass interiores',
#   'lead designer'],
#  'design purchaser': ['designer purchaser',
#   'planner purchaser',
#   'designers budget',
#   'producer project manager',
#   'general manager purchaser',
#   'designer pm gc',
#   'producer'],
#  'chief': ['designer engineer',
#   'chief engineering',
#   'chief eng',
#   'chief engineer',
#   'engineer',
#   'chief physician',
#   'solution engineer',
#   'president',
#   'doctor',
#   'vice president'],
#  'recommend': ['recommender',
#   'recommendation',
#   'recommend recommend specific products technologies the solution'],
#  'medical solution provider': ['medical solution provider \u200b'],
#  'component video wall': ['part video wall', 'video wall'],
#  'producer project manager': ['program project manager',
#   'project head',
#   'project engineer'],
#  'replacement tv': ['replacing tv'],
#  'architect consultant': ['project manager designer',
#   'contractor owner',
#   'general manager project manager',
#   'project administrator',
#   'architect owner',
#   'project manager estimator',
#   'office manager',
#   'building owner',
#   'construction manager',
#   'signage subcontractor p'],
#  'maintenance': ['maintenance technician', 'maintenance supervisor'],
#  'surgery professional': ['surgery professional \u200b'],
#  'distribution': ['distributor', 'distributor quotation'],
#  'conference room': ['conference', 'conference table'],
#  'consult': ['consulting',
#   'consultant',
#   'director purchaser',
#   'consultant purchaser'],
#  'general manager decision maker': ['project designer',
#   'systems designer',
#   'designer',
#   'technology designer',
#   'design decision maker',
#   'technical decision maker',
#   'technical marketing',
#   'decision maker',
#   'developer'],
#  'installation purchaser': ['system installer',
#   'system designer integrator',
#   'installer sales rep',
#   'it integrator',
#   'installer system integrator'],
#  'facilitator': ['facility manager',
#   'project facilitator',
#   'facilitator installation services',
#   'facilities',
#   'support facilitator designer',
#   'facility administrator'],
#  'main end user the product': ['primary end user'],
#  'commercial director': ['engineering technical executive',
#   'system engineer',
#   'it director',
#   'director operations',
#   'ordering manager',
#   'director',
#   'creative director',
#   'director lodging',
#   'managing director'],
#  'building owner': ['property owner',
#   'business owner',
#   'owner',
#   'parts coordinator',
#   'product owner',
#   'owner representation'],
#  'design install': ['research install',
#   'design build',
#   'design install training support'],
#  'facilities': ['facilities operations'],
#  'purchase': ['purchasers',
#   'purchase dept',
#   'purchasing',
#   'purchasing agent',
#   'purchaser'],
#  'administration': ['administrative',
#   'administrative assistant',
#   'integration'],
#  'integration': ['integrator'],
#  'sales': ['salesman', 'sales manager'],
#  'lead': ['engineering director',
#   'lead engineer',
#   'team leader',
#   'team lead',
#   'leader'],
#  'admin': ['admin assistant', 'it admin'],
#  'purchaser': ['purchasing manager',
#   'purchasing supervisor',
#   'purchasing director',
#   'purchasing authority'],
#  'reseller': ['seller installer', 'reseller integrator'],
#  'execution': ['executive'],
#  'medical imaging specialist': ['specialist medical imaging'],
#  'imaging administrator': ['it administrator',
#   'it specialist',
#   'systems administrator',
#   'platform administrator',
#   'network administrator',
#   'procurement specialist'],
#  'interior designer': ['interior stylist'],
#  'federal government contractor': ['general manager',
#   'general contractor',
#   'sub contractor',
#   'managing contractor',
#   'managing partner'],
#  'marketing coordinator': ['marketing operations', 'purchasing coordinator'],
#  'development coordinator procurement': ['project researcher'],
#  'product owner': ['product researcher'],
#  'assist serving food': ['serving food'],
#  'it support': ['support'],
#  'community theater': ['home theater'],
#  'event marketing': ['product marketing', 'field marketing'],
#  'manufacturer': ['manufacturing factory plant', 'supplier'],
#  'it': ['it tech', 'office it', 'it department'],
#  'display screen': ['display screen control'],
#  'furnish install': ['purchase install'],
#  'hardware': ['hardware selection', 'hardware design engineer'],
#  'display': ['display screen', 'display products'],
#  'parts coordinator': ['service coordinator'],
#  'engineering': ['technical sales'],
#  'it manager': ['sales operations', 'sales rep'],
#  'manger': ['ranger 2'],
#  'director operations': ['regional director operations'],
#  'technician': ['technology consultant'],
#  'product research': ['research installation', 'research'],
#  'operation': ['operations manager', 'operations'],
#  'lead designer': ['designer creative technologist',
#   'specifier integrator',
#   'solution provider',
#   'solutions provider specifier'],
#  'ceo': ['coo', 'ceo founder'],
#  'engagement executive': ['sales executive', 'operations executive'],
#  'advertising': ['marketing executive',
#   'sale',
#   'advertising promotions team',
#   'marketing'],
#  'finance': ['finance executive'],
#  'contributor': ['distribution'],
#  'gc': ['gm'],
#  'tech': ['tech service'],
#  'facility administrator': ['pacs administrator'],
#  'managing director': ['managing employee'],
#  'developer': ['developer property', 'software developer', 'real estate'],
#  'graphic design': ['graphic color art'],
#  'education': ['educator', 'teacher', 'tester'],
#  'technical advisor reseller': ['vendor reseller'],
#  'end user': ['main end user the product', 'user'],
#  'teacher': ['teaching'],
#  'hr': ['hr posting'],
#  'photographer': ['photos'],
#  'buyer': ['buyer coordinating', 'dealer'],
#  'design installation company': ['planning installation'],
#  'principal': ['principal charge'],
#  'network administrator': ['systems design'],
#  'stores': ['store promotions'],
#  'cctv monitoring': ['cctv view'],
#  'hotel manager': ['hotel tv'],
#  'sign company': ['signage manager'],
#  'digital display vs signage need': ['digital signage']}

# %%
# 방법 2-3. 방법 1-3과 동일
standard = 0.6

cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)
cosine_scores = np.array(cosine_scores)
np.fill_diagonal(cosine_scores, np.nan)

cos_similar = dict()
cosine_scores = pd.DataFrame(cosine_scores)
c = customer_stop.copy()
while cosine_scores.max().max() > standard:
    i = cosine_scores.max(axis = 1).idxmax()
    j = cosine_scores.iloc[i,:].idxmax()
    
    cosine_scores.iloc[i, j] = 0
    cosine_scores.iloc[j, i] = 0

    idx, del_idx = [i, j] if len(c[i]) <= len(c[j]) else [j, i]
    
    if c[idx] == "":
        idx, del_idx = del_idx, idx
    elif c[idx] in cos_similar.keys():
        cos_similar[c[del_idx]] = cos_similar[c[idx]]
    else:
        cos_similar[c[del_idx]] = c[idx]
    
    cosine_scores = cosine_scores.drop(del_idx).drop(del_idx, axis = 1).reset_index(drop = True)
    cosine_scores.columns = list(range(len(cosine_scores)))
    del c[del_idx]
    
c = [cos_similar[i] if i in cos_similar.keys() else i for i in customer_stop]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_job_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_job] # country 기준 conversion으로 변경
len_6 = len(set(customer_job_t)); len_6
# Out:
# 317

# %%
manage_trans_6 = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in manage]

# %%
test_func(cos_similar)
# Out:
# {'design': ['art design', 'design build', 'designer', 'design purchaser'],
#  'art design': ['creation design',
#   'arts design',
#   'art e design',
#   'art installation'],
#  'medical solution provider': ['medical solution provider',
#   'medical solution provider \u200b'],
#  'program project manager': ['program project management'],
#  'research': ['research development', 'product research', 'research install'],
#  'business development': ['business development'],
#  'project head': ['project manager',
#   'project director',
#   'project designer',
#   'project lead'],
#  'tech': ['tech',
#   'information technology',
#   'technical',
#   'it tech',
#   'tech service',
#   'energy'],
#  'community social services': ['community social services'],
#  'director': ['director it',
#   'it director',
#   'director finance',
#   'creative director',
#   'director lodging'],
#  'estimator': ['estimator'],
#  'healthcare services': ['healthcare services', 'healthcare professionals'],
#  'installer': ['installer',
#   'installation purchaser',
#   'installer sales rep',
#   'seller installer'],
#  'media': ['media communication'],
#  'clinical specialist': ['medical imaging specialist'],
#  'military protective services': ['military protective services'],
#  'product marketing': ['product management'],
#  'radiology professional': ['radiology professional'],
#  'sourcing': ['sourcing procurement'],
#  'quality assurance': ['quality assurance'],
#  'human resources': ['human resources'],
#  'media communication': ['media communications'],
#  'system engineer': ['systems engineer', 'systems administrator'],
#  'design purchaser': ['designer purchaser',
#   'director purchaser',
#   'design consultant'],
#  'design engineer': ['designer engineer'],
#  'project manager': ['projection manager',
#   'r project manager',
#   'project sales manager',
#   'project manager principal',
#   'project management',
#   'v project manager',
#   'program project manager',
#   'owner project manager',
#   'digital project manager',
#   'project administrator',
#   'project coordinator',
#   'designer project manager',
#   'project manager estimator'],
#  'program project management': ['project management program project management'],
#  'recommend': ['recommender',
#   'recommendation',
#   'recommend recommend specific products technologies the solution'],
#  'project lead': ['it project lead'],
#  'chief engineer': ['chief engineering',
#   'system engineer',
#   'principal engineer',
#   'engineering technical executive',
#   'director engineering'],
#  'designer': ['designers', 'design engineer'],
#  'information technology': ['it information technology',
#   'information technology \u200b'],
#  'video wall': ['part video wall', 'component video wall'],
#  'replacing tv': ['replacement tv'],
#  'designer project manager': ['project manager designer'],
#  'contractor': ['contractor owner',
#   'signage subcontractor p',
#   'sub contractor'],
#  'engineering': ['engineering technical'],
#  'maintenance supervisor': ['maintenance technician'],
#  'surgery professional': ['surgery professional \u200b'],
#  'contributor': ['distributor', 'distribution'],
#  'conference': ['conference room', 'conference table'],
#  'consult': ['consulting', 'consultant'],
#  'project designer': ['project architect', 'project engineer'],
#  'seller installer': ['system installer',
#   'designer installer',
#   'purchaser it installer'],
#  'facility manager': ['facility administrator', 'construction manager'],
#  'end user': ['primary end user', 'main end user the product'],
#  'owner project manager': ['general manager project manager'],
#  'building owner': ['property owner', 'business owner'],
#  'research install': ['research installation'],
#  'facilities': ['facilities operations', 'facilitator'],
#  'designer installer': ['retailer installer'],
#  'purchaser': ['purchasers'],
#  'administration': ['administrative'],
#  'integrator': ['integration', 'it integrator'],
#  'sales': ['salesman', 'sales operations', 'sales engineering', 'sales rep'],
#  'director engineering': ['engineering director'],
#  'admin': ['admin assistant', 'it admin'],
#  'architect': ['architect owner',
#   'architect consultant',
#   'architect ass interiores'],
#  'purchasing manager': ['purchasing coordinator',
#   'purchasing director',
#   'purchasing supervisor'],
#  'execution': ['executive'],
#  'medical imaging specialist': ['specialist medical imaging'],
#  'maintenance': ['maintenance supervisor'],
#  'design install': ['engineering design install',
#   'design install training support'],
#  'it admin': ['it administrator'],
#  'interior stylist': ['interior designer'],
#  'system designer integrator': ['installer system integrator'],
#  'systems design': ['systems designer'],
#  'general manager': ['general management'],
#  'owner': ['building owner', 'product owner', 'owner representation'],
#  'marketing': ['marketing operations', 'advertising'],
#  'product researcher': ['project researcher'],
#  'product research': ['product researcher'],
#  'purchase': ['purchase dept', 'purchasing', 'purchase install', 'purchaser'],
#  'technology designer': ['technology consultant'],
#  'serving': ['serving food'],
#  'manager': ['management',
#   'it manager',
#   'site manager',
#   'sales manager',
#   'ordering manager',
#   'general manager',
#   'resource manager'],
#  'support': ['it support'],
#  'home theater': ['community theater'],
#  'decision maker': ['design decision maker',
#   'technical decision maker',
#   'general manager decision maker'],
#  'chief': ['chief eng', 'chief physician', 'chief engineer', 'president'],
#  'sales manager': ['sales executive'],
#  'manufacturer': ['manufacturing factory plant'],
#  'display screen': ['display screen control'],
#  'account management': ['account executive manager'],
#  'hardware': ['hardware selection', 'hardware design engineer'],
#  'display': ['display screen', 'display products'],
#  'service coordinator': ['marketing coordinator'],
#  'technical sales': ['technical marketing'],
#  'accounting': ['account management', 'accounts payable'],
#  'field marketing': ['field outside sales'],
#  'manger': ['ranger 2'],
#  'director operations': ['regional director operations'],
#  'lead designer': ['lead engineer'],
#  'office manager': ['operations manager'],
#  'ceo': ['coo', 'ceo founder'],
#  'leader': ['team leader'],
#  'site manager': ['office manager'],
#  'it integrator': ['system designer integrator', 'specifier integrator'],
#  'parts coordinator': ['service coordinator'],
#  'it specialist': ['clinical specialist', 'it hardware technician'],
#  'solution advisor': ['solution provider', 'solution engineer'],
#  'tv studio manager': ['producer project manager'],
#  'operation': ['operations'],
#  'lead': ['team lead', 'leader', 'lead designer'],
#  'software solution': ['software developer'],
#  'network administrator': ['platform administrator'],
#  'planner purchaser': ['consultant purchaser'],
#  'director purchaser': ['general manager purchaser'],
#  'event marketing': ['product marketing', 'field marketing'],
#  'finance': ['finance executive'],
#  'surgeon': ['surgery professional'],
#  'energy': ['renewable energy'],
#  'purchasing agent': ['purchasing manager'],
#  'gc': ['gm'],
#  'supplier': ['supplier installation', 'manufacturer'],
#  'general contractor': ['federal government contractor'],
#  'managing employee': ['managing contractor', 'imaging administrator'],
#  'project facilitator': ['project team member'],
#  'developer': ['developer property'],
#  'graphic design': ['graphic color art'],
#  'educator': ['education'],
#  'planner': ['planner purchaser'],
#  'design consultant': ['technology designer'],
#  'vendor reseller': ['technical advisor reseller'],
#  'head': ['head technology', 'project head'],
#  'commercial director': ['director operations'],
#  'teacher': ['teaching', 'educator'],
#  'it': ['office it', 'it department'],
#  'sale': ['stores', 'marketing'],
#  'hr': ['hr posting'],
#  'program directors': ['commercial director'],
#  'photos': ['photographer'],
#  'buyer': ['buyer coordinating', 'dealer'],
#  'procurement': ['procurement specialist'],
#  'studio manager': ['tv studio manager', 'facility manager'],
#  'user': ['end user'],
#  'reseller': ['reseller integrator'],
#  'engineer': ['engineering'],
#  'principal': ['principal charge'],
#  'advertising': ['advertising promotions team'],
#  'tester': ['teacher'],
#  'producer': ['designer producer'],
#  'planning installation': ['design installation company'],
#  'cctv view': ['cctv monitoring'],
#  'hotel tv': ['hotel manager'],
#  'facilitator': ['project facilitator'],
#  'sign company': ['signage manager'],
#  'digital signage': ['digital display vs signage need'],
#  'it software': ['software solution'],
#  'managing director': ['managing employee'],
#  'engagement executive': ['operations executive'],
#  'it department': ['department secretary']}

# %%
# manage란 단어를 포함한 단어들이 방법에 따라 어떻게 분류되었는지
manage = pd.DataFrame([manage, manage_trans_1, manage_trans_2, manage_trans_3, manage_trans_4, manage_trans_5, manage_trans_6]).T
manage.columns = ["original","방법1","방법2","방법3","방법4","방법5","방법6"]
manage
# Out:
#                                              original  \
# 0                                 a/v project manager
# 1                           account executive/manager
# 2                                  account management
# 3                                    asset management
# 4                                  by project manager
# 5                                           comanager
# 6                                construction manager
# 7                           designer/ project manager
# 8                             digital project manager
# 9                                    facility manager
# 10                                 general management
# 11                                    general manager
# 12                   general manager (decision maker)
# 13                  general manager - project manager
# 14                         general manager- purchaser
# 15                                      hotel manager
# 16                                         it manager
# 17                                         management
# 18                                            manager
# 19                                     office manager
# 20                                 operations manager
# 21                                   ordering manager
# 22                            owner / project manager
# 23                           producer/project manager
# 24                                 product management
# 25                                 product_management
# 26                     program and project management
# 27                     program_and_project management
# 28                     program_and_project_management
# 29                        program_and_project_manager
# 30                                     project manage
# 31                                 project management
# 32  project management program and project management
# 33                                    project manager
# 34                        project manager / estimator
# 35                        project manager / principal
# 36                           project manager/designer
# 37                              project sales/manager
# 38                                 projection manager
# 39                                 purchasing manager
# 40                                r&d project manager
# 41                           reseorot general manager
# 42                                   resource manager
# 43                                      sales manager
# 44                                    signage manager
# 45                                       site manager
# 46                                     studio manager
# 47                                  tv studio manager
#
#                            방법1                         방법2  \
# 0            v project manager           v project manager
# 1    account executive manager   account executive manager
# 2           account management          account management
# 3             asset management            asset management
# 4            v project manager           v project manager
# 5                    comanager                   comanager
# 6         construction manager        construction manager
# 7                     designer                    designer
# 8            v project manager           v project manager
# 9       facility administrator      facility administrator
# 10          general management          general management
# 11             general manager             general manager
# 12             general manager             general manager
# 13             general manager                    designer
# 14             general manager           v project manager
# 15               hotel manager               hotel manager
# 16                    director                          it
# 17          general management          account management
# 18                    director                          it
# 19                   office it                   office it
# 20             field marketing                    director
# 21            ordering manager            ordering manager
# 22                  contractor                  contractor
# 23                    designer           v project manager
# 24          general management          general management
# 25          general management          general management
# 26  program project management  program project management
# 27  program project management  program project management
# 28  program project management  program project management
# 29  program project management  program project management
# 30              project manage              project manage
# 31  program project management  program project management
# 32  program project management                  management
# 33  program project management           v project manager
# 34  program project management           v project manager
# 35  program project management           v project manager
# 36  program project management                    designer
# 37  program project management           v project manager
# 38          projection manager          projection manager
# 39                  purchasing                  purchasing
# 40  program project management           v project manager
# 41             general manager                    designer
# 42            resource manager            resource manager
# 43  program project management                          it
# 44             signage manager             signage manager
# 45                site manager                site manager
# 46              studio manager              studio manager
# 47              studio manager              studio manager
#
#                            방법3                        방법4  \
# 0              project manager          v project manager
# 1    account executive manager  account executive manager
# 2                   management  account executive manager
# 3             asset management  account executive manager
# 4                      manager          v project manager
# 5                    comanager                  comanager
# 6         construction manager          v project manager
# 7             project designer                  architect
# 8      digital project manager                  architect
# 9             facility manager                facilitator
# 10                  management  account executive manager
# 11             general manager  account executive manager
# 12              decision maker             decision maker
# 13             general manager  account executive manager
# 14             general manager  account executive manager
# 15                    hotel tv              hotel manager
# 16                          it        commercial director
# 17                  management  account executive manager
# 18                     manager  account executive manager
# 19                   office it  account executive manager
# 20                  operations  account executive manager
# 21            ordering manager  account executive manager
# 22             project manager        commercial director
# 23                    producer  account executive manager
# 24                  management  account executive manager
# 25                  management  account executive manager
# 26  program project management  account executive manager
# 27  program project management  account executive manager
# 28  program project management  account executive manager
# 29             project manager  account executive manager
# 30              project manage          v project manager
# 31                  management  account executive manager
# 32  program project management  account executive manager
# 33                     manager  account executive manager
# 34                   estimator  account executive manager
# 35                   principal  account executive manager
# 36    designer project manager  account executive manager
# 37               sales manager  account executive manager
# 38          projection manager  account executive manager
# 39                  purchasing         purchasing manager
# 40             project manager        commercial director
# 41             general manager   reseorot general manager
# 42            resource manager  account executive manager
# 43                       sales  account executive manager
# 44             signage manager            signage manager
# 45                site manager  account executive manager
# 46              studio manager        commercial director
# 47              studio manager        commercial director
#
#                                방법5                         방법6
# 0                v project manager             project manager
# 1        account executive manager          account management
# 2        account executive manager                  accounting
# 3        account executive manager            asset management
# 4                v project manager                project head
# 5                        comanager                   comanager
# 6             architect consultant            facility manager
# 7                       art design             project manager
# 8                v project manager             project manager
# 9                      facilitator              studio manager
# 10       account executive manager             general manager
# 11   federal government contractor                     manager
# 12  general manager decision maker              decision maker
# 13            architect consultant       owner project manager
# 14                design purchaser          director purchaser
# 15                   hotel manager                    hotel tv
# 16               v project manager                     manager
# 17       account executive manager                     manager
# 18               v project manager                     manager
# 19            architect consultant                site manager
# 20                       operation              office manager
# 21             commercial director                     manager
# 22               v project manager             project manager
# 23                design purchaser           tv studio manager
# 24       account executive manager           product marketing
# 25       account executive manager           product marketing
# 26                      art design     program project manager
# 27                      art design     program project manager
# 28                      art design     program project manager
# 29        producer project manager             project manager
# 30               v project manager              project manage
# 31                      art design             project manager
# 32               v project manager  program project management
# 33               v project manager                project head
# 34            architect consultant             project manager
# 35                       architect             project manager
# 36            architect consultant    designer project manager
# 37               v project manager             project manager
# 38                       architect             project manager
# 39                       purchaser            purchasing agent
# 40                       architect             project manager
# 41        reseorot general manager    reseorot general manager
# 42               v project manager                     manager
# 43                           sales                     manager
# 44                    sign company                sign company
# 45               v project manager                     manager
# 46               v project manager              studio manager
# 47               v project manager              studio manager

# %%
# 방법 3. https://zephyrus1111.tistory.com/191 -> SequenceMatcher 단어 유사도 => 비슷한 것 같음
# 방법 4. 텍스트 군집화 -> K-means
# https://romg2.github.io/mlguide/03_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-%EC%99%84%EB%B2%BD%EA%B0%80%EC%9D%B4%EB%93%9C-08.-%ED%85%8D%EC%8A%A4%ED%8A%B8%EB%B6%84%EC%84%9D-%EB%AC%B8%EC%84%9C-%EA%B5%B0%EC%A7%91%ED%99%94/
# 위 방법이 더 좋지 않을까?

# %%
print(f"original 카테고리 수 : {original}")
print(f"번역 후 카테고리 수 : {original_trans}")
print(f"방법 1-1 카테고리 수 : {len_1}")
print(f"방법 1-2 카테고리 수 : {len_2}")
print(f"방법 1-3 카테고리 수 : {len_3}")
print(f"방법 2-1 카테고리 수 : {len_4}")
print(f"방법 2-2 카테고리 수 : {len_5}")
print(f"방법 2-3 카테고리 수 : {len_6}")
# Out:
# original 카테고리 수 : 561
# 번역 후 카테고리 수 : 527
# 방법 1-1 카테고리 수 : 294
# 방법 1-2 카테고리 수 : 313
# 방법 1-3 카테고리 수 : 323
# 방법 2-1 카테고리 수 : 257
# 방법 2-2 카테고리 수 : 251
# 방법 2-3 카테고리 수 : 317

# %% [markdown]
# # Customer_Position

# %%
original = len(set(train.customer_position))

# %%
# 번역
position_lst = set(train.customer_position)
position_lst_trans = [translate_func(i) if not pd.isna(i) else i for i in position_lst] 
position_dict = pd.DataFrame([position_lst, position_lst_trans]).T
position_dict.columns = ["position_lst", "position_lst_trans"]
position_dict = position_dict.set_index("position_lst").T.to_dict()
train.customer_position = [position_dict[i]["position_lst_trans"] if not pd.isna(i) else i for i in train.customer_position]

position_lst = set(submission.customer_position)
position_lst_trans = [translate_func(i) if not pd.isna(i) else i for i in position_lst] 
position_dict = pd.DataFrame([position_lst, position_lst_trans]).T
position_dict.columns = ["position_lst", "position_lst_trans"]
position_dict = position_dict.set_index("position_lst").T.to_dict()
submission.customer_position = [position_dict[i]["position_lst_trans"] if not pd.isna(i) else i for i in submission.customer_position]

# %%
original_trans = len(set(train.customer_position))

# %%
# 방법 1. TfidfVectorizer와 코사인 유사도 이용
# 글자만 고려
customer_set = sorted(list(set(train.customer_position.dropna())))
le_train = len(customer_set)

# 특수문자 제거 및 토큰화
customer_re = [re.sub(r"[.,~!@#$%^&*\(\)_+=\-~|\\\"\';:\?/\<\>\[\]\{\}]", " ", customer) for customer in customer_set]
customer_re = [customer.strip().lower() for customer in customer_re]
customer_token = [WordPunctTokenizer().tokenize(i) for i in customer_re]

# 불용어 사전
stop = stopwords.words('english')

# 불용어 제거
customer_stop = []
for i in customer_token:
    for j in i:
        sent = i
        if j in stop: # 불용어 사전에 있으면 제거
            sent.remove(j)
    customer_stop.append(sent)
customer_stop = [" ".join(i) for i in customer_stop] # 다시 결합

# 문장 벡터화
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(customer_stop)

# %%
# 방법 1-1. 유사하다고 생각되는 모든 값을 그룹화
# 장점 : 카테고리수를 많이 줄일 수 있음, 단점 : 오차가 큼
# 알고리즘
# n*n으로 구성된 유사도 matrix를 순차적으로 돌아가며 확인한다.
# 유사도 기준(standard)를 넘으면 cos_similar에 key를 i번째 값, value를 j 번째 값으로 넣고, customer_stop의 j번째 값을 i번째 값으로 변경


# job들을 각각 하나씩 비교해 코사인 유사도가 standard를 넘는 것을 추출 및 그룹화 되는 첫번째 값으로 전부 변경
standard = 0.6
cos = cosine_similarity(tfidf_matrix, tfidf_matrix) > standard
cos_similar = dict()
c = customer_stop.copy() # 테스트를 위한 copy
for i in range(len(cos)):
    for j in range(i+1, len(cos[i])):
        if c[i] == "" or c[j] == "":
            pass
        elif cos[i][j] and c[i] in cos_similar.keys():
            cos_similar[c[j]] = cos_similar[c[i]]
            c[j] = c[i]
        elif cos[i][j]:
            cos_similar[c[j]] = c[i]
            c[j] = c[i]


# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_position_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_position] # country 기준 conversion으로 변경
len_1 = len(set(customer_position_t)); len_1
# Out:
# 94

# %%
# 어떤 값이 변화되었는지 확인하기 위한 코드
# key 값이 변화된 값, value가 변화되기 전의 값으로 구성
def test_func(cos_similar):
    test = dict()
    for i in cos_similar.keys():
        if cos_similar[i] not in test.keys():
            test[cos_similar[i]] = [i]
        else:
            test[cos_similar[i]] += [i]
    return test
test_func(cos_similar)
# Out:
# {'vice president': ['president', 'vice president'],
#  'architect consultant': ['consultant'],
#  'you prof': ['prof'],
#  'assistant professor': ['assistant professor english', 'professor'],
#  'associate professor': ['associate professor electronics engg',
#   'assistant professor',
#   'professor mathematics'],
#  'business development': ['business development sales'],
#  'business partner': ['partner'],
#  'management': ['product management'],
#  'ceo founder': ['founder'],
#  'co founder': ['ceo founder'],
#  'commercial consultant': ['architect consultant'],
#  'commercial end user': ['end user'],
#  'decision influencer': ['decision influencer'],
#  'decision maker': ['decision maker'],
#  'director': ['principal director'],
#  'education': ['education professional'],
#  'general manager': ['manager'],
#  'math physics teacher': ['physics teacher'],
#  'physics mathematics teacher': ['math physics teacher', 'teacher'],
#  'science teacher': ['physics mathematics teacher']}

# %%
# 방법 1-2. 유사하다고 생각되는 모든 값을 그룹화

standard = 0.6
cos = cosine_similarity(tfidf_matrix, tfidf_matrix)

cos = np.array(cos)
np.fill_diagonal(cos, np.nan)

cos_similar = dict()
cos = pd.DataFrame(cos)
c = customer_stop.copy()
while cos.max().max() > standard:
    i = cos.max(axis = 1).idxmax()
    j = cos.iloc[i,:].idxmax()
    
    if customer_stop[i] == "" or customer_stop[j] == "":
        pass
    elif c[i] in cos_similar.keys():
        cos_similar[c[j]] = cos_similar[c[i]]
    else:
        cos_similar[c[j]] = c[i]
    
    cos.iloc[i, j] = 0
    cos.iloc[j, i] = 0

c = [cos_similar[i] if i in cos_similar.keys() else i for i in c]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_position_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_position] # country 기준 conversion으로 변경
len_2 = len(set(customer_position_t)); len_2
# Out:
# 94

# %%
test_func(cos_similar)
# Out:
# {'vice president': ['vice president', 'president'],
#  'decision influencer': ['decision influencer'],
#  'decision maker': ['decision maker'],
#  'commercial end user': ['end user'],
#  'business development': ['business development sales'],
#  'assistant professor': ['assistant professor english',
#   'professor',
#   'professor mathematics'],
#  'business partner': ['partner'],
#  'math physics teacher': ['physics teacher'],
#  'education': ['education professional'],
#  'architect consultant': ['consultant'],
#  'you prof': ['prof'],
#  'management': ['product management'],
#  'general manager': ['manager'],
#  'science teacher': ['teacher'],
#  'director': ['principal director'],
#  'co founder': ['founder'],
#  'associate professor': ['associate professor electronics engg']}

# %%
# 방법 1-3. 길이가 적은 값으로 그룹화
# 장점 : 핵심 단어로 분류가 가능
# 단점 : 더 깐깐하게 그룹화
# 알고리즘
# 가장 유사도가 높은 두 단어를 추출
# 두 단어 중 길이가 짧은 것을 value, 길이가 긴 것을 key로 설정해 길이가 긴 것으로 짧은 것으로 변환할 수 있도록 함
# 길이가 짧은 단어의 유사도를 두고, 길이가 긴 단어의 유사도는 삭제 -> 그래야 길이가 긴 단어와 유사도가 높은 단어가 포함되지 않음
standard = 0.6
cos = cosine_similarity(tfidf_matrix, tfidf_matrix)

cos = np.array(cos)
np.fill_diagonal(cos, np.nan)

cos_similar = dict()
cos = pd.DataFrame(cos)
c = customer_stop.copy()
while cos.max().max() > standard:
    i = cos.max(axis = 1).idxmax()
    j = cos.iloc[i,:].idxmax()
    
    cos.iloc[i, j] = 0
    cos.iloc[j, i] = 0

    idx, del_idx = [i, j] if len(c[i]) <= len(c[j]) else [j, i]
    
    if c[idx] == "":
        idx, del_idx = del_idx, idx
    elif c[idx] in cos_similar.keys():
        cos_similar[c[del_idx]] = cos_similar[c[idx]]
    else:
        cos_similar[c[del_idx]] = c[idx]
    
    cos = cos.drop(del_idx).drop(del_idx, axis = 1).reset_index(drop = True)
    cos.columns = list(range(len(cos)))
    del c[del_idx]
    
c = [cos_similar[i] if i in cos_similar.keys() else i for i in customer_stop]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_position_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_position] # country 기준 conversion으로 변경
len_3 = len(set(customer_position_t)); len_3
# Out:
# 92

# %%
test_func(cos_similar)
# Out:
# {'president': ['vice president'],
#  'decision influencer': ['decision influencer'],
#  'decision maker': ['decision maker'],
#  'end user': ['commercial end user'],
#  'business development': ['business development sales'],
#  'assistant professor': ['assistant professor english'],
#  'partner': ['business partner'],
#  'physics teacher': ['physics mathematics teacher', 'math physics teacher'],
#  'education': ['education professional'],
#  'consultant': ['commercial consultant', 'architect consultant'],
#  'prof': ['you prof'],
#  'management': ['product management'],
#  'manager': ['general manager'],
#  'teacher': ['physics teacher', 'science teacher'],
#  'director': ['principal director'],
#  'professor': ['associate professor',
#   'assistant professor',
#   'professor mathematics'],
#  'founder': ['ceo founder', 'co founder']}

# %%
# 방법 2. 사전학습모델 SentenceTransformer
# 단어의 숨겨진 의미까지 파악해 위 방법보다 유연
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
customer_set = sorted(list(set(train.customer_position.dropna())))
le_train = len(customer_set)

# 특수문자 제거 및 토큰화
customer_re = [re.sub(r"[.,~!@#$%^&*\(\)_+=\-~|\\\"\';:\?/\<\>\[\]\{\}]", " ", customer) for customer in customer_set]
customer_re = [customer.strip().lower() for customer in customer_re]
customer_token = [WordPunctTokenizer().tokenize(i) for i in customer_re]

# 불용어 사전
stop = stopwords.words('english')

# 불용어 제거
customer_stop = []
for i in customer_token:
    for j in i:
        sent = i
        if j in stop: # 불용어 사전에 있으면 제거
            sent.remove(j)
    customer_stop.append(sent)
customer_stop = [" ".join(i) for i in customer_stop] # 다시 결합

embeddings = model.encode(customer_stop, convert_to_tensor=True)

# %%
# 방법 2-1. 방법 1-1과 동일
standard = 0.6

cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)
cosine_scores = cosine_scores>standard
cos_similar = dict()
c = customer_stop.copy() # 테스트를 위한 copy
for i in range(len(cos)):
    for j in range(i+1, len(cosine_scores[i])):
        if c[i] == "" or c[j] == "":
            pass
        elif cosine_scores[i][j] and c[i] in cos_similar.keys():
            cos_similar[c[j]] = cos_similar[c[i]]
            c[j] = c[i]
        elif cosine_scores[i][j]:
            cos_similar[c[j]] = c[i]
            c[j] = c[i]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_position_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_position] # country 기준 conversion으로 변경
len_4 = len(set(customer_position_t)); len_4
# Out:
# 78

# %%
test_func(cos_similar)
# Out:
# {'vice president': ['president', 'vice president'],
#  'academic specialist': ['medical imaging specialist', 'surgery professional'],
#  'architect consultant': ['architecture consult'],
#  'assistant professor': ['assistant professor english',
#   'associate professor',
#   'assistant professor'],
#  'business development': ['business development sales'],
#  'management': ['manager', 'product management'],
#  'ceo founder': ['co founder', 'founder'],
#  'chemistry teacher': ['math physics teacher',
#   'physics mathematics teacher',
#   'physics teacher',
#   'science teacher',
#   'teacher'],
#  'chief executive officer': ['leadership executive office owner'],
#  'commercial end user': ['end user'],
#  'consultant': ['consulting'],
#  'decision influencer': ['decision maker', 'decision influencer'],
#  'education': ['education professional',
#   'educator',
#   'education',
#   'professional trainer',
#   'maths lecturer',
#   'guest faculty',
#   'professor mathematics',
#   'senior lecturer',
#   'professor'],
#  'prof': ['chemistry teacher'],
#  'employee': ['trainee'],
#  'engineering': ['technical'],
#  'entry level': ['entrylevel'],
#  'exhibition': ['exhibitiontv'],
#  'general manager': ['management'],
#  'guest faculty': ['physics faculty'],
#  'homeowner': ['owner']}

# %%
# 방법 2-2. 방법 1-2와 동일

standard = 0.6

cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)
cosine_scores = np.array(cosine_scores)
np.fill_diagonal(cosine_scores, np.nan)

cos_similar = dict()
cosine_scores = pd.DataFrame(cosine_scores)
c = customer_stop.copy()
while cosine_scores.max().max() > standard:
    i = cosine_scores.max(axis = 1).idxmax()
    j = cosine_scores.iloc[i,:].idxmax()
    
    
    if customer_stop[i] == "" or customer_stop[j] == "":
        pass
    elif customer_stop[i] in cos_similar.keys():
        cos_similar[c[j]] = cos_similar[c[i]]
    else:
        cos_similar[c[j]] = c[i]
    
    cosine_scores.iloc[i, j] = 0
    cosine_scores.iloc[j, i] = 0
    
c = [cos_similar[i] if i in cos_similar.keys() else i for i in customer_stop]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_position_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_position] # country 기준 conversion으로 변경
len_5 = len(set(customer_position_t)); len_5
# Out:
# 79

# %%
test_func(cos_similar)
# Out:
# {'decision influencer': ['decision maker', 'decision influencer'],
#  'vice president': ['vice president', 'president'],
#  'math physics teacher': ['physics teacher',
#   'professor',
#   'maths lecturer',
#   'professor mathematics',
#   'physics faculty',
#   'senior lecturer'],
#  'entry level': ['entrylevel'],
#  'chemistry teacher': ['physics mathematics teacher', 'math physics teacher'],
#  'owner': ['homeowner'],
#  'assistant professor': ['associate professor', 'assistant professor english'],
#  'business development': ['business development sales'],
#  'exhibition': ['exhibitiontv'],
#  'prof': ['science teacher'],
#  'general manager': ['manager'],
#  'consultant': ['consulting'],
#  'commercial end user': ['end user'],
#  'architect consultant': ['architecture consult'],
#  'education': ['education professional',
#   'professional trainer',
#   'educator',
#   'teacher',
#   'teacher middle school coordinator'],
#  'management': ['product management'],
#  'ceo founder': ['co founder', 'founder'],
#  'employee': ['trainee'],
#  'medical imaging specialist': ['surgery professional'],
#  'engineering': ['technical'],
#  'academic specialist': ['medical imaging specialist'],
#  'chief executive officer': ['leadership executive office owner']}

# %%
# 방법 2-3. 방법 1-3과 동일
standard = 0.6

cosine_scores = util.pytorch_cos_sim(embeddings, embeddings)
cosine_scores = np.array(cosine_scores)
np.fill_diagonal(cosine_scores, np.nan)

cos_similar = dict()
cosine_scores = pd.DataFrame(cosine_scores)
c = customer_stop.copy()
while cosine_scores.max().max() > standard:
    i = cosine_scores.max(axis = 1).idxmax()
    j = cosine_scores.iloc[i,:].idxmax()
    
    cosine_scores.iloc[i, j] = 0
    cosine_scores.iloc[j, i] = 0

    idx, del_idx = [i, j] if len(c[i]) <= len(c[j]) else [j, i]
    
    if c[idx] == "":
        idx, del_idx = del_idx, idx
    elif c[idx] in cos_similar.keys():
        cos_similar[c[del_idx]] = cos_similar[c[idx]]
    else:
        cos_similar[c[del_idx]] = c[idx]
    
    cosine_scores = cosine_scores.drop(del_idx).drop(del_idx, axis = 1).reset_index(drop = True)
    cosine_scores.columns = list(range(len(cosine_scores)))
    del c[del_idx]
    
c = [cos_similar[i] if i in cos_similar.keys() else i for i in customer_stop]

# train의 customer_job 변경
customer_df_train = pd.DataFrame([customer_set, c]).T  # DataFrame 생성
customer_df_train.columns = ["customer_set", "c"]            # colunm명 생성
customer_dict_train = customer_df_train.set_index("customer_set").T.to_dict()   # dict형으로 변환
customer_position_t = [customer_dict_train[i]["c"] if not pd.isna(i) and customer_dict_train[i]["c"] != "" else i for i in train.customer_position] # country 기준 conversion으로 변경
len_6 = len(set(customer_position_t)); len_6
# Out:
# 83

# %%
test_func(cos_similar)
# Out:
# {'decision maker': ['decision maker', 'decision influencer'],
#  'president': ['vice president'],
#  'physics teacher': ['physics mathematics teacher',
#   'math physics teacher',
#   'science teacher'],
#  'entrylevel': ['entry level'],
#  'owner': ['homeowner'],
#  'assistant professor': ['associate professor', 'assistant professor english'],
#  'business development': ['business development sales'],
#  'exhibition': ['exhibitiontv'],
#  'manager': ['management', 'general manager'],
#  'physics faculty': ['physics teacher'],
#  'prof': ['professor'],
#  'consultant': ['consulting'],
#  'end user': ['commercial end user'],
#  'guest faculty': ['physics faculty'],
#  'architect consultant': ['architecture consult'],
#  'educator': ['education professional', 'education'],
#  'co founder': ['ceo founder'],
#  'maths lecturer': ['senior lecturer', 'professor mathematics'],
#  'trainee': ['employee'],
#  'teacher': ['chemistry teacher',
#   'educator',
#   'teacher middle school coordinator'],
#  'founder': ['co founder'],
#  'surgery professional': ['medical imaging specialist'],
#  'technical': ['engineering'],
#  'chief executive officer': ['leadership executive office owner']}

# %%
print(f"original 카테고리 수 : {original}")
print(f"번역 후 카테고리 수 : {original_trans}")
print(f"방법 1-1 카테고리 수 : {len_1}")
print(f"방법 1-2 카테고리 수 : {len_2}")
print(f"방법 1-3 카테고리 수 : {len_3}")
print(f"방법 2-1 카테고리 수 : {len_4}")
print(f"방법 2-2 카테고리 수 : {len_5}")
print(f"방법 2-3 카테고리 수 : {len_6}")
# Out:
# original 카테고리 수 : 117
# 번역 후 카테고리 수 : 114
# 방법 1-1 카테고리 수 : 94
# 방법 1-2 카테고리 수 : 94
# 방법 1-3 카테고리 수 : 92
# 방법 2-1 카테고리 수 : 78
# 방법 2-2 카테고리 수 : 79
# 방법 2-3 카테고리 수 : 83
